# %% [markdown]
# ### ***Author:***
# ![Portfolio Banner.png](<attachment:Portfolio Banner.png>)

# %% [markdown]
# *Date*: 25-10-2023
#
# #                               ***EXPLORATORY DATA ANALYSIS***
# ### ***Project Name: Apple AppStore Android App Data (1.2 Million+ App Data)***

# %% [markdown]
# ### ***1.0-Project Summary:***
#
# `In a dynamic market environment, understanding the past is crucial for shaping the future. This project involves a detailed Exploratory Data Analysis (EDA) of our Apple AppStore Android App Data (1.2 Million+ App Data). `
#
# `The Apple AppStore Android App Data dataset contains information on over 1.2 million apps available on the Play Store. The data includes app name, category, rating, number of reviews, size, and developer name. This dataset can be used to explore trends in the mobile app market, identify popular app categories, and analyze user sentiment towards different apps.`

# %% [markdown]
# ### ***2.0-Research Questions:***
# 1. Top app accordding to Primary_Genre
# 2. Top app according to content ratings
# 3. Find all app with 5.0 average user rating
# 4. Findout free and paid apps ratio
# 5. Correlation between size of app and its ratings
# 6. Correlation between Average_User_Rating and Primary_Genre

# %% [markdown]
# ### ***3.0-Dataset***

# %% [markdown]
# ---
#   >The  *DATASET* was downloaded from the following [link](https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps)
# ---

# %% [markdown]
# ### ***4.0-Libraries***
# There are so many libraries that used in Exploratory Data Analysis. Despite of this, used most important libraries for this EDA project.
#
# #### ***4.1-Libraries USED***:
# 1. Pandas
# 2. Numpy
# 3. Matplotrlib
# 4. Seaborn
# 5. Scipy
# 6. Plotly

# %% [markdown]
# ### ***5.0-Purpose of EDA***
# > 1. Identify Free Apps with Good Ratings\
#     `To identify free apps with good ratings, use the following criteria:`
#
# * *Rating:* The app has a rating of 4.0 or higher out of 5.
# * *Number of reviews:* The app has at least 100 reviews.
# * *Content rating:* The app is rated for ages 12+ or lower.
#
# > 2. Analyze Free Apps with High Installer Reviews\
#     `To analyze free apps with high installer reviews, use the following steps:`
#
# * *Identify the most popular free apps:* Sorting the apps by the number of installs or reviews.
# * *Read the reviews for each app:* Pay attention to the positive and negative reviews.
# * *Identify the common themes in the reviews:* What do people like and dislike about the app?
# * *Use the information from the reviews to improve the app:* Make changes to the app based on the feedback from users.
#
# > 3. Determine Age Group Preferences\
#     `To determine age group preferences, use the following steps:`
#
# * Segment the users by age group: Using the age field in the dataset.
# * Calculate the percentage of users in each age group who have installed and reviewed an app.
# * Compare the percentages of users in each age group who have installed and reviewed an app. This will help identify which age groups are more likely to install and review apps.
#
# > 4. Identify Popular App Genres/Categories\
#     `To identify popular app genres/categories, use the following steps:`
#
# * Group the apps by genre or category. This by using the genre or category field in the dataset.
# * Calculate the number of apps in each genre or category.
# * Sort the genres or categories by the number of apps. This will help identify the most popular app genres/categories.
#
# > 5. Explore the Correlation between Free and Paid App Reviews\
#     `To explore the correlation between free and paid app reviews, use the following steps:`
#
# * Calculate the average rating for free and paid apps.
# * Plot the average rating for free and paid apps.
# * Calculate the correlation coefficient between the average rating for free and paid apps. This will help determine the strength of the correlation between the two variables.

# %% [markdown]
# ### ***6.0-Importing Libraries***
#
#     First, import libraries before statrting EDA. This libraries are helpful determine the insights.

# %%
#import libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import plotly as px

# %% [markdown]
# #### ***7.0-Import the Data From Databases:***
#
# There are several types of databases available, each designed to serve specific purposes and cater to different needs. Here are some of the commonly used types of databases:
#
# 1. Relational Databases (RDBMS):
# 2. NoSQL Databases:
# 3. Object-Oriented Databases:
# 4. Hierarchical Databases:
# 5. Time-Series Databases:
#
# In the case study, an open data source was used, and the data from that source was stored in a CSV file.

# %% [markdown]
# ### ***7.1-Data Loading, Exploration and Cleaning:***
#  ↪ Load the csv file with the pandas.
#
#  ↪ Creating the dataframe and understanding the data present in the dataset using pandas.
#
#  ↪ Dealing with the missing data, outliers and the incorrect records.

# %%
#load dataset
app_store = pd.read_csv('appleAppData.csv')

# %% [markdown]
# ### ***8.0-Explore the Dataset:***

# %% [markdown]
# #### ***8.1-Checkout the First 5 rows of the dataset:***

# %%
app_store.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %% [markdown]
# #### ***8.2-Viewing Dataset Vertically To Know the Features Of Dataset***

# %%
app_store.head().T
# Out:
#                                                                          0  \
# App_Id                                                 com.hkbu.arc.apaper
# App_Name                                                    A+ Paper Guide
# AppStore_Url             https://apps.apple.com/us/app/a-paper-guide/id...
# Primary_Genre                                                    Education
# Content_Rating                                                          4+
# Size_Bytes                                                      21993472.0
# Required_IOS_Version                                                   8.0
# Released                                              2017-09-28T03:02:41Z
# Updated                                               2018-12-21T21:30:36Z
# Version                                                              1.1.2
# Price                                                                  0.0
# ...

# %% [markdown]
# #### **8.3 Checkout the Complete info of the dataset**

# %%
#check info
app_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# #### Observations:
# - DeveloperId is int64 , but it should be in object.
# - Convert Size_Bytes to *MB* for better understanging of data.

# %% [markdown]
# ### ***8.4-Checkout value_counts of primary genre and content rating:***

# %%
app_store['Primary_Genre'].value_counts().sort_values(ascending=False)
# Out:
# Primary_Genre
# Games                     193749
# Business                  128297
# Education                 119174
# Utilities                  94007
# Lifestyle                  84565
# Food & Drink               73157
# Health & Fitness           60724
# Productivity               59430
# Entertainment              53147
# Shopping                   49537
# Finance                    44984
# Travel                     43726
# Sports                     31455
# Music                      29898
# Medical                    27995
# Photo & Video              25957
# Social Networking          25429
# News                       20423
# Reference                  18615
# Navigation                 12636
# Stickers                   12407
# Book                       11472
# Weather                     3563
# Graphics & Design           2781
# Developer Tools             1951
# Magazines & Newspapers      1297
# Name: count, dtype: int64

# %%
#check value count of content rating
app_store['Content_Rating'].value_counts().sort_values(ascending=False)
# Out:
# Content_Rating
# 4+               980971
# 17+              124127
# 12+               89570
# 9+                35698
# Not yet rated        10
# Name: count, dtype: int64

# %% [markdown]
# #### ***8.5-Columns Of Dataset:***
# - Let's see the column names which can be easily copied later on from Dataset.

# %%
app_store.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %% [markdown]
# #### ***8.6-Dimensions of Dataset:***

# %%
print(f"Our dataframe dimensions: {app_store.shape[0]} rows x {app_store.shape[1]} columns.")
# Out:
# Our dataframe dimensions: 1230376 rows x 21 columns.

# %% [markdown]
# #### ***8.7-Statistical View:***

# %%
app_store.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# ### ***9.0-Identifing Missing Values & Dealing:***

# %% [markdown]
# #### ***9.1-Find Missing Values:***

# %%
app_store.isnull().sum().sort_values(ascending = False)
# Out:
# Developer_Website          643988
# Developer_Url                1109
# Price                         490
# Size_Bytes                    224
# Released                        3
# App_Name                        1
# Free                            0
# Current_Version_Score           0
# Reviews                         0
# Average_User_Rating             0
# Developer                       0
# DeveloperId                     0
# App_Id                          0
# Currency                        0
# Version                         0
# Updated                         0
# Required_IOS_Version            0
# Content_Rating                  0
# Primary_Genre                   0
# AppStore_Url                    0
# Current_Version_Reviews         0
# dtype: int64

# %% [markdown]
# #### *Obsevation:*
#     - Observe some values is missing in the different columns of the dataset.
# - App_Name    |                    1
# - Released    |                    3
# - Size_Bytes  |                  224
# - Price       |                  490
# - Developer_Url |                1109
# - Developer_Website |          643988

# %% [markdown]
# #### ***9.2-Missing Values In Percentage:***
#      We are going to view missing values of dataset in percentage format that would be easily understanding in how much data is missing in specific columns of dataset.

# %%
# null values in percentage
sorted_missing_percent = ((app_store.isnull().sum() / len(app_store)) * 100).sort_values(ascending=False)
print(sorted_missing_percent)
# Out:
# Developer_Website          52.340748
# Developer_Url               0.090135
# Price                       0.039825
# Size_Bytes                  0.018206
# Released                    0.000244
# App_Name                    0.000081
# Free                        0.000000
# Current_Version_Score       0.000000
# Reviews                     0.000000
# Average_User_Rating         0.000000
# Developer                   0.000000
# DeveloperId                 0.000000
# App_Id                      0.000000
# Currency                    0.000000
# Version                     0.000000
# Updated                     0.000000
# Required_IOS_Version        0.000000
# Content_Rating              0.000000
# Primary_Genre               0.000000
# AppStore_Url                0.000000
# Current_Version_Reviews     0.000000
# dtype: float64

# %% [markdown]
# #### ***9.3-Visualize Missing Data Via Heatmap:***

# %%
# Visualize missing data in heatmap ,# Create a heatmap of missing data
plt.figure(figsize=(10, 6))
sns.heatmap(app_store.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Data Heatmap')
plt.show()

# %% [markdown]
# #### *Observation*
#     Half of the values is missing in the developer_website column is 52.3%. However, some data is missing in other columns but the percentage is very small.
# - Developer_Website          52.340748
# - Developer_Url               0.090135
# - Price                       0.039825
# - Size_Bytes                  0.018206
# - Released                    0.000244
# - App_Name                    0.000081

# %% [markdown]
# ### ***9.4-Dealing Missing Data:***

# %% [markdown]
# #### ***9.4.1-Deal with Developer_website column:***

# %%
# remove Developer_Website column
app_store = app_store.drop('Developer_Website', axis=1)

# %%
# column names
app_store.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %% [markdown]
# #### ***9.4.2-Dealing App_name column:***

# %%
# remove missing row in the column
app_store = app_store.dropna(subset=['App_Name'])

# %% [markdown]
# #### ***9.4.3-Dealing Released column:***

# %%
# remove missing row in the column
app_store = app_store.dropna(subset=['Released'])

# %% [markdown]
# #### ***9.4.4-Dealing with Size_Bytes:***

# %%
# remove missing row in the column
app_store = app_store.dropna(subset=['Size_Bytes'])

# %%
app_store.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Url              1109
# Price                       266
# App_Name                      0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# Free                          0
# Currency                      0
# App_Id                        0
# Version                       0
# Updated                       0
# Released                      0
# Required_IOS_Version          0
# Size_Bytes                    0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %% [markdown]
# ### ***10-Featured Engineering:***

# %% [markdown]
# ### ***10.1-Converting Size_Bytes To Megabytes (MB):***

# %%
app_store['Size_MB'] = app_store['Size_Bytes'].apply(lambda x: (float(x) / 1024)/1024)

# %% [markdown]
# #### ***10.2-Creating New Column Of Type:***
# - Its column is create to understand that the app is free or paid

# %%
app_store['Type'] = app_store['Price'].apply(lambda price: 'Free' if price == 0 else 'Paid')

# %% [markdown]
# ### ***Research QUESTIONS:***
# we have findout following research questions
# 1. Top app accordding to Primary_Genre
# 2. Top app according to content ratings
# 3. Find all app with 5.0 average user rating
# 4. Findout free and paid apps ratio
# 5. Correlation between size of app and its ratings
# 6. Correlation between Average_User_Rating and Primary_Genre

# %% [markdown]
# ### ***11.0-Insights of Data:***

# %% [markdown]
# #### ***11.1-Top-Apps According to Prime_Genre column:***

# %%
app_store['Primary_Genre'].value_counts().sort_values(ascending=False)
# Out:
# Primary_Genre
# Games                     193528
# Business                  128297
# Education                 119174
# Utilities                  94007
# Lifestyle                  84565
# Food & Drink               73157
# Health & Fitness           60724
# Productivity               59430
# Entertainment              53145
# Shopping                   49537
# Finance                    44984
# Travel                     43726
# Sports                     31455
# Music                      29898
# Medical                    27995
# Photo & Video              25957
# Social Networking          25428
# News                       20422
# Reference                  18615
# Navigation                 12636
# Stickers                   12407
# Book                       11472
# Weather                     3563
# Graphics & Design           2781
# Developer Tools             1951
# Magazines & Newspapers      1297
# Name: count, dtype: int64

# %% [markdown]
# #### ***11.1.1-Top 10 Primary_Genre via Barplots:***

# %%
# Count the number of apps in each genre
genre_counts = app_store['Primary_Genre'].value_counts().head(10)

# Plot the top 5 genres
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='grey')
plt.title('Top 5 Most Popular Genres Based on Number of Apps')
plt.xlabel('Genre')
plt.ylabel('Number of Apps')
plt.xticks(rotation=45)

for i, bar in enumerate(plt.gca().patches):
    plt.annotate(str(bar.get_height()), 
                 (bar.get_x() + bar.get_width()/2, bar.get_height()), 
                 xytext=(0, 5), 
                 textcoords="offset points", 
                 ha="center", 
                 va="bottom",
                 arrowprops=dict(arrowstyle="-"))

plt.show()

# %% [markdown]
# #### *Observations:*
#     Observe from the provided data on the "Primary_Genre" column:
#
# 1. Most Common Genres: The data shows that "Games," "Business," and "Education" are the most common primary genres in the dataset. These genres have a significantly higher number of apps compared to others, indicating their prevalence in the app store.
#
# 2. Diverse App Ecosystem: The presence of a wide range of primary genres, such as "Health & Fitness," "Food & Drink," "Travel," "Music," and "Weather," highlights the diversity of apps available in the app store. This diversity caters to various user interests and needs.
#
# 3. Niche Categories: Some primary genres, like "Magazines & Newspapers" and "Developer Tools," have a relatively lower number of apps, indicating that they represent more niche or specialized categories within the app ecosystem.
#
# These observations provide insights into the distribution of app genres in the dataset and can be useful for understanding market trends, user preferences, and potential areas of focus for app development or marketing strategies.

# %% [markdown]
# ### ***11.2-Top App According to Content Ratings:***

# %%
app_store['Content_Rating'].value_counts().sort_values(ascending=False)
# Out:
# Content_Rating
# 4+               980866
# 17+              124126
# 12+               89515
# 9+                35634
# Not yet rated        10
# Name: count, dtype: int64

# %% [markdown]
# #### ***11.2.1-Top App Barplots:***

# %%
# Data
content_ratings = ['4+', '17+', '12+', '9+', 'Not yet rated']
counts = [980866, 124126, 89515, 35634, 10]

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(y=counts, x=content_ratings, palette='viridis')

# Customize the plot
plt.xlabel('Number of Apps')
plt.ylabel('Content Rating')
plt.title('Apps by Content Rating')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_7804\1907802004.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=counts, x=content_ratings, palette='viridis')

# %% [markdown]
# #### *Observations:*
#     Observations from the provided data on the "Content_Rating" column:
#
# 1. Dominance of All-Ages Content: The most common content rating is *4+*, which suggests that the majority of apps in the dataset are suitable for users of all ages. This indicates a focus on family-friendly content in the app store, which can have a broad user base.
#
# 2. Presence of Age-Restricted Content: While *4+* is the most common rating, there is still a notable number of apps with age restrictions, such as *17+* and *12+.* This suggests that there is a significant number of apps intended for more mature audiences or those with certain age-appropriate restrictions.
#
# 3. Sparse "Not Yet Rated" Category: The "Not yet rated" category has a very small count, indicating that most apps have clear content ratings. This is important for transparency and helping users make informed choices about the content they consume or allow for their children.
#
# These observations provide insights into the diversity of content ratings in the app store, with the majority of apps being family-friendly but also catering to users of different age groups and preferences. The presence of clear content ratings is important for user safety and appropriate app selection.

# %% [markdown]
# ### ***11.3-App with 5.0 Average User Rating:***

# %%
# value count of average user rating
app_store['Average_User_Rating'].value_counts()
# Out:
# Average_User_Rating
# 0.00000    684235
# 5.00000    184277
# 1.00000     34169
# 3.00000     27022
# 4.00000     24531
#             ...
# 4.26359         1
# 4.33188         1
# 3.99315         1
# 4.87190         1
# 4.82733         1
# Name: count, Length: 45015, dtype: int64

# %%
# Average_User_Rating unique values
app_store['Average_User_Rating'].unique()
# Out:
# array([0.     , 5.     , 4.78132, ..., 4.00352, 3.91608, 4.82733])

# %%
# Filter the DataFrame to select apps with a 5.0 Average_User_Rating
top_rated_apps = app_store[app_store['Average_User_Rating'] == 5.0]

print(top_rated_apps.shape)
# Out:
# (184277, 22)

# %%
top_rated_apps.head(10)
# Out:
#                                     App_Id  \
# 1                      com.dmitriev.abooks
# 20        com.gentouchstudios.aaabcvuilite
# 21           com.alpigames.fairylandpuzzle
# 24  com.partnergomobilephoneapps.bandbcafe
# 28              com.hemsedalsite.AABMobile
# 32   com.jhdigitalsolutions.lastenaakkoset
# 33                  com.aalisiri.audiobook
# 39      com.divy.AartiBhajanChalisaSangrah
# 54           net.brilliant-exams.bestexams
# 57                 com.b737ng.aircraftapps
#
#                                     App_Name  \
# 1                                    A-Books
# 20  Aaabc Vui Lite - Bang chu cai tieng viet
# 21             AAA³ Little Ponies & Unicorns
# 24                                  B&B Cafe
# 28                                AAB Mobile
# 32                       Aakkospeli Lapsille
# 33                       Aalisiri Audiobooks
# 39              Aarti Bhajan Chalisa Sangrah
# 54                            B.E.S.T. Exams
# ...

# %% [markdown]
# #### *Observations:*
# The provided data on the "Average_User_Rating" column contains information about the distribution of user ratings for various apps. Here's a description in sentences:
#
# 1. Common Ratings: The most common user rating in the dataset is 0.00000, which suggests a substantial number of apps have received no user ratings or have an average rating of zero. This could indicate that many apps have not been rated by users.
#
# 2. Highly Rated Apps: There is a significant number of apps (184,277) with a perfect rating of 5.00000, indicating that a substantial portion of apps in the dataset have received very positive user feedback and are considered highly-rated.
#
# 3. Variety of Ratings: The dataset exhibits a wide range of average user ratings, including ratings of 1.00000, 3.00000, and 4.00000, as well as various decimal ratings. This diversity reflects the varying degrees of user satisfaction and evaluation of apps in the app store.
#
# 4. Extensive Range of Ratings: The dataset contains a large number of unique rating values (45015), which suggests that users have provided a wide array of ratings for the apps. This demonstrates the granularity of the rating system and the potential for a nuanced understanding of user preferences.
#
# 5. Sparse High Ratings: While there is a substantial number of highly-rated apps with a perfect 5.00000 score, the presence of zero ratings and lower ratings (e.g., 1.00000) also highlights the challenges and diversity in app ratings and user experiences.
#
# In summary, the "Average_User_Rating" column represents a broad spectrum of user ratings, with a substantial number of highly-rated apps but also apps with no or lower ratings, reflecting the complexity of user feedback in the app store.

# %% [markdown]
# ### ***11.4-Free vs Paid Apps:***

# %%
# findout free and paid apps:
# Calculate the ratio of free and paid apps
ratio = app_store['Type'].value_counts(normalize=True)

# Display the ratio
print(ratio)
# Out:
# Type
# Free    0.916459
# Paid    0.083541
# Name: proportion, dtype: float64

# %% [markdown]
# #### ***11.4.1-Pie chart:***

# %%
# Make pie chart for visualizing
proportions = [0.916459, 0.083541]
labels = ['Free', 'Paid']
colors = ['skyblue', 'lightcoral']

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(proportions, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Customize the plot
plt.title('Free vs Paid Apps')
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.

# Show the plot
plt.show()

# %% [markdown]
# #### *Observations:*
# The provided data represents the proportion of free vs paid apps in a dataset with the following characteristics:
#
# 1. Dominance of Free Apps: Free apps account for the majority of the dataset, making up approximately 91.65% of the total. This indicates that a substantial portion of the apps in the dataset are offered to users at no cost.
#
# 2. Limited Presence of Paid Apps: On the other hand, paid apps constitute a relatively small proportion of the dataset, at approximately 8.35%. This suggests that a minority of the apps come with a price tag, and they are less common compared to free alternatives.
#
# 3. Pricing Strategy Distribution: The data provides insights into the pricing strategy employed by app developers in the dataset, highlighting a significant disparity between free and paid apps. This information can be valuable for understanding the market dynamics and strategies within the app industry.

# %% [markdown]
# ### ***11.5-Correlation Size of App vs Ratings:***

# %%
# Calculate the correlation
correlation = app_store['Size_MB'].corr(app_store['Average_User_Rating'])

# Display the correlation
print("Correlation between Size (MB) and Average User Rating:", correlation)
# Out:
# Correlation between Size (MB) and Average User Rating: 0.04847878035622731

# %% [markdown]
# #### ***11.5.1-Correlation Size of Apps vs Ratings:***

# %%
# Create a scatter plot using Seaborn
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Size_MB', y='Average_User_Rating', data=app_store, alpha=0.5)

# Customize the plot
plt.xlabel('Size (MB)')
plt.ylabel('Average User Rating')
plt.title('Correlation between Size (MB) and Average User Rating')

# Show the plot
plt.show()

# %% [markdown]
# #### *Observations:*
#
# The correlation between "Size (MB)" and "Average User Rating" is approximately 0.0485, and it can be described in the following three points:
#
# 1. Weak Positive Correlation: The correlation coefficient of approximately 0.0485 indicates a weak positive correlation between the size of mobile applications (in megabytes) and their average user ratings. This means that, on average, as the size of an app increases, there is a slight tendency for user ratings to also increase. However, the correlation is quite close to zero, suggesting that the relationship is not strong.
#
# 2. Limited Influence of Size on User Ratings: The positive correlation suggests that larger apps are slightly more likely to receive higher user ratings, but the effect is relatively small. In practical terms, app size is not a primary determinant of user satisfaction. Other factors such as app functionality, performance, and user experience likely play more significant roles in user ratings.
#
# 3. Consideration of Other Factors: While a positive correlation is observed, it's important to recognize that app size is just one of many factors that can influence user ratings. App developers and stakeholders should consider various elements, including functionality, design, and user feedback, in addition to size, to improve user satisfaction and app performance.

# %% [markdown]
# ### ***11.6-Correlation Average_User_Rating vs Primary_Genre:***

# %%
import scipy.stats as stats

# Assuming you have a DataFrame 'df' with columns 'Average_User_Rating' and 'Primary_Genre'

# Perform ANOVA test
f_statistic, p_value = stats.f_oneway(*[group['Average_User_Rating'] for name, group in app_store.groupby('Primary_Genre')])

# Display the results
print("F-statistic:", f_statistic)
print("p-value:", p_value)

# Interpret the results
if p_value < 0.05:
    print("There is a statistically significant relationship between Primary_Genre and Average_User_Rating.")
else:
    print("There is no statistically significant relationship between Primary_Genre and Average_User_Rating.")
# Out:
# F-statistic: 2261.6957823356543
# p-value: 0.0
# There is a statistically significant relationship between Primary_Genre and Average_User_Rating.

# %%
# Create a violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(x='Primary_Genre', y='Average_User_Rating', data=app_store)

# Customize the plot
plt.xlabel('Primary Genre')
plt.ylabel('Average User Rating')
plt.title('Average User Ratings by Primary Genre')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %% [markdown]
# #### *Observations:*
# Based on the results of the ANOVA (Analysis of Variance) test, which examined the relationship between *Primary_Genre* and *Average_User_Rating,* the following conclusions can be drawn:
#
# 1. Highly Statistically Significant Relationship: The calculated **F-statistic of 2261.70** is considerably larger than expected by random chance. The extremely low **p-value of 0.0** indicates that there is a highly statistically significant relationship between the primary genre of mobile applications and their average user ratings. This means that the choice of primary genre has a substantial influence on user ratings.
#
# 2. Influence of Genre on User Ratings: The results suggest that the primary genre of an app significantly impacts its average user rating. Some genres may be associated with higher average ratings, while others may have lower ratings. This information is valuable for app developers and stakeholders, as it highlights the importance of understanding how genre selection can affect user satisfaction and perception.
#
# 3. Further Analysis Opportunities: While the test establishes a significant relationship, additional post-hoc tests or in-depth analyses can help uncover which specific genres tend to have higher or lower ratings. Further exploration may provide actionable insights for app developers and decision-makers in optimizing user experiences and app performance within particular genres.

# %% [markdown]
# ### ***12.0-Conclusion:***

# %% [markdown]
# 1. In this dataset, the **Primary_Genre** column reveals a diverse app ecosystem with a wide range of app genres. While **Games,** **Business,** and **Education** dominate as the most common genres, the presence of numerous other genres, including more niche categories like **Magazines & Newspapers** and **Developer Tools,** underscores the app store's ability to cater to a broad spectrum of user interests and needs. This diversity in app genres highlights the richness of the mobile app market and the potential for developers to target various genres to meet specific user demands.
#
# 2. The prevalence of **4+** content ratings, signifying apps suitable for all ages, suggests a strong emphasis on family-friendly content in the dataset, while the limited presence of **Not yet rated** category highlights a commitment to clear content ratings for user transparency.
#
# 3. The data indicates that a significant proportion of apps in the dataset are free (approximately 91.65%), while paid apps constitute a minority (about 8.35%), highlighting the prevalence of free apps in the app store.
#
# 4. The weak positive correlation of 0.0485 suggests that, on average, larger app sizes have a slight tendency to be associated with higher user ratings, though the relationship is not substantial.
#
# 5. The analysis indicates a highly statistically significant relationship between the choice of app's primary genre and its average user rating, as evidenced by the high F-statistic and a p-value of 0.
